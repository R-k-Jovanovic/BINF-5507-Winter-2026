# %%
import pandas as pd

airbnb = pd.read_csv("listings_summary.csv")

airbnb

# airbnb.head(n= 15)

# help(airbnb.head)

airbnb.columns

airbnb['minimum_nights'].mean()
# airbnb['minimum_nights'].median()
# Out:
# np.float64(25.35643748835476)

# %%
# license_levels = airbnb['license'].unique()
# print(license_levels)
airbnb['minimum_nights'].median()
# Out:
# np.float64(28.0)

# %%
airbnb['minimum_nights'].plot.box()
# Out:
# <Axes: >
